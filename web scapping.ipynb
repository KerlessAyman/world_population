# %% [markdown]
# # Web Scrapping

# %% [markdown]
# ## importing Libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## inputing url

# %%
url = "https://www.worldometers.info/world-population/world-population-by-year/"
headers = { "User-Agent": "Mozilla/5.0" }

resp = requests.get(url, headers=headers)
soup = BeautifulSoup(resp.content, "html.parser")

# %% [markdown]
# ## Extracting the First HTML Table using BeautifulSoup

# %%
table = soup.find("table")
table
# Out:
# <table class="datatable w-full border border-zinc-200" data-locale="en" data-options='{"searchable":false,"sortable":false,"pageSize":false}' data-sort-col="-1" data-sort-dir="asc" id=""> <thead> <tr> <th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false"> <span>Year</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Population</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Yearly % Change</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Net Change</span> </th><th class="px-2 border-e border-zinc-200 font-semibold border-b-3 py-1" data-sortable="false" data-type="number"> <span>Density (P/Km²)</span> </th> </tr> </thead> <tbody> <tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b"> 2025 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="8231613070" dir="ltr"> 8,231,613,070 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="85" dir="ltr"> 0.85% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="69640498" dir="ltr"> 69,640,498 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="55.26798086477776" dir="ltr"> 55 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b"> 2024 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="8161972572" dir="ltr"> 8,161,972,572 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="87" dir="ltr"> 0.87% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="70237642" dir="ltr"> 70,237,642 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="54.80040668725661" dir="ltr"> 55 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b"> 2023 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="8091734930" dir="ltr"> 8,091,734,930 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="88" dir="ltr"> 0.88% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="70327738" dir="ltr"> 70,327,738 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="54.328823217402984" dir="ltr"> 54 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b"> 2022 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="8021407192" dir="ltr"> 8,021,407,192 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="84" dir="ltr"> 0.84% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="66958801" dir="ltr"> 66,958,801 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="53.856634832818585" dir="ltr"> 54 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b"> 2021 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="7954448391" dir="ltr"> 7,954,448,391 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="86" dir="ltr"> 0.86% </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="67447099" dir="ltr"> 67,447,099 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" data-order="53.40706587216329" dir="ltr"> 53 </td> </tr><tr> <td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b"> 2020 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b font-bold" data-order="7887001292" dir="ltr"> 7,887,001,292 </td><td class="px-2 border-e border-zinc-200 text-end py-1.5 border-b" da ...

# %% [markdown]
# ## Extracting Table Headers from an HTML Table

# %%
headers = [th.text.strip() for th in table.find_all("th")]
headers
# Out:
# ['Year', 'Population', 'Yearly % Change', 'Net Change', 'Density (P/Km²)']

# %% [markdown]
# ## Populating a Pandas DataFrame from HTML Table Rows

# %%
rows = []
for tr in table.find_all("tr")[1:]:
    cols = [td.text.strip().replace(",", "") for td in tr.find_all("td")]
    if cols:
        rows.append(cols)


df = pd.DataFrame(rows, columns=headers)
df
# Out:
#     Year  Population Yearly % Change Net Change Density (P/Km²)
# 0   2025  8231613070           0.85%   69640498              55
# 1   2024  8161972572           0.87%   70237642              55
# 2   2023  8091734930           0.88%   70327738              54
# 3   2022  8021407192           0.84%   66958801              54
# 4   2021  7954448391           0.86%   67447099              53
# ..   ...         ...             ...        ...             ...
# 88   900   240000000                                          2
# 89   800   220000000                                          1
# 90   700   210000000                                          1
# 91   600   200000000                                          1
# 92   200   190000000                                          1
#
# [93 rows x 5 columns]

# %%
df_clean = df.dropna(subset=['Yearly % Change', 'Net Change'])

# %%
# Assuming 'df' is your DataFrame:
df_clean.to_csv("world_population_data.csv", index=False, encoding='utf-8')

# %%
import pyodbc

conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    r'SERVER=KEROPC\SQLEXPRESS;' 
    'DATABASE=world_population;'
    'Trusted_Connection=yes;'
)

cursor = conn.cursor()
cursor.execute("SELECT @@VERSION")
for row in cursor:
    print(row)

conn.close()
# Out:
# ('Microsoft SQL Server 2014 - 12.0.2000.8 (X64) \n\tFeb 20 2014 20:04:26 \n\tCopyright (c) Microsoft Corporation\n\tExpress Edition (64-bit) on Windows NT 6.3 <X64> (Build 22621: ) (Hypervisor)\n',)
